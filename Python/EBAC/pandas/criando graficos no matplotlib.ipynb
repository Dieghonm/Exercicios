# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib notebook
#comando do jupter para permitir interações com os graficos no matplotlib

# %%
data = [1,2,3,3,2,3,4,5]
plt.plot(data)
#Plotagem é o processo de criação de gráficos ou representações visuais de dados.
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1 = fig.add_subplot(2,2,1)
# cria um grafico em branco

# %%
type(ax1)
# Out:
# matplotlib.axes._axes.Axes

# %%
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')
#preenche o ultimo grafico com os paramtros
#o primeiro parametro e um array  com os dados, e o segundo um dado estetico
#onde cada letra tem e um parametro aperte shift+tab para vera s opcoes
# o k significa que e preto, mas poderia ser g, par verde, b para azul, r vermelhoc ciano, m magenta, y amarelo ou w opara branco
# o -- e para ser tracejado, mas tem muitas outras opçoes
#ou plt.plot?

# %%
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=.3)
_= ax2.scatter(np.random.randn(30), np.arange(30) + 3 * np.random.randn(30))

# %%
plt.close('all')
#-------------encerra todos os graficos para nao tem mais alteraçoes--------------------------------

# %%
fig, axes = plt.subplots(2,3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#preenchenco os graficos aleatoriamente
fig, axes = plt.subplots(2,2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500), bins=50, color = 'b', alpha=0.9)
    
#ajusta os espaçoes do grafico
plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close('all')

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from numpy.random import randn
plt.plot(randn(30).cumsum(), 'go--')

# %%
plt.close('all')

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
#linha preta
plt.plot(data, 'b-', drawstyle='steps-post', label='steps-post')
#linha azul
plt.legend(loc='best')
# legenda
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#troca as nomeclaturas do eixo X
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['ano 1', 'ano 2', 'ano 3', 'ano 4', 'ano 5'],
                           rotation= 30, fontsize = 'small')

# %%
#troca o titulo do grafico
ax.set_title('titulo do grafico')
#nomeia o eixo x do grafico
ax.set_xlabel('periodo')
# Out:
# Text(0.5, 0, 'periodo')

# %%
plt.close('all')

# %%
fig = plt.figure(); ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum(),'k--', label='True')
ax.plot(np.random.randn(1000).cumsum(),'k.', label='three')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.legend(loc='best')

# %%
# para salvar o grafico plt.savefig('figura.jpg')

# %%
#--------------------graficos basicos-----------------------------------------

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips['tip_pct'] = tips['tip'] / tips['total_bill'] - tips['tip']
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2 -0.950553
# 1       10.34  1.66    Male     No  Sun  Dinner     3 -1.499458
# 2       21.01  3.50    Male     No  Sun  Dinner     3 -3.333413
# 3       23.68  3.31    Male     No  Sun  Dinner     2 -3.170220
# 4       24.59  3.61  Female     No  Sun  Dinner     4 -3.463192

# %%
df = pd.DataFrame({'col1':[10,20,30]}, index = [1,2,3])
df
# Out:
#    col1
# 1    10
# 2    20
# 3    30

# %%
df.plot.bar()
# Out:
# <Axes: >
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.DataFrame({'A':[10,15], 'B':[20,25],'C':[30,35]}, index = [1,2])
df
# Out:
#     A   B   C
# 1  10  20  30
# 2  15  25  35

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
tips['day'].value_counts().sort_index().plot.bar()
# Out:
# <Axes: >

# %%
#plotagem com o Seaborn

# %%
sns.countplot(x='day', data=tips[tips.tip_pct < 1])
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
plt.close('all')
plt.rc('figure', figsize=(10,8))
fig, axes = plt.subplots(2,2)

sns.countplot(ax = axes[0,0], x='day', data = tips)
sns.countplot(ax = axes[0,1], x='sex', data = tips)
sns.countplot(ax = axes[1,0], x='smoker', data = tips)
sns.countplot(ax = axes[1,1], x='time', data = tips)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
plt.close('all')
plt.rc('figure', figsize=(10,8))
fig, axes = plt.subplots(2,2)

sns.countplot(ax = axes[0,0], x='day', data = tips)
sns.barplot(ax = axes[0,1], x='day', y='tip_pct', data = tips)
sns.barplot(ax = axes[1,0], x='day', y='tip',data = tips)
sns.barplot(ax = axes[1,1], x='day', y='tip', estimator=sum ,data = tips, errorbar = None)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
tips['day'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='day'>

# %%
from matplotlib.ticker import PercentFormatter

df = pd.DataFrame({'contagem': [ 43,20,174,5,2,1,1,0]})
df.index = ['Produto com defeito', 'Produto errado', 'Tempo de entrega', 
           'Horario de entrega', 'mau atendimento', 'valor errado', 'Nao serve', 'Desistencia']

df = df.sort_values(by='contagem', ascending=False)
df['pctacum'] = df['contagem'].cumsum()/df['contagem'].sum()*100

df
# Out:
#                      contagem     pctacum
# Tempo de entrega          174   70.731707
# Produto com defeito        43   88.211382
# Produto errado             20   96.341463
# Horario de entrega          5   98.373984
# mau atendimento             2   99.186992
# valor errado                1   99.593496
# Nao serve                   1  100.000000
# Desistencia                 0  100.000000

# %%
fig, ax = plt.subplots()

ax.bar(df.index, df['contagem'])
ax2 = ax.twinx()
ax2.plot(df.index, df['pctacum'], color='r', marker='o')
ax2.yaxis.set_major_formatter(PercentFormatter())


ax.tick_params(axis='x', rotation = 30)
ax2.tick_params(axis='y', colors='r')
plt.show()
