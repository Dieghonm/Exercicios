# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

totalAlunos = 100

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
#Calcule o percentual de acerto dos alunos por assunto.
df_mat / 0.24
df_por / 0.18
df_geo / 0.8
df_ing / 0.8
df_his / 0.8
df_fis / 0.8
df_qui / 0.8
# Out:
#     Qt_acertos
# 0         3.75
# 1        10.00
# 2         5.00
# 3        10.00
# 4         3.75
# ..         ...
# 95        3.75
# 96        3.75
# 97        6.25
# 98       13.75
# 99        2.50
#
# [100 rows x 1 columns]

# %%
# 2) Seu código aqui
# Calcule o total de acertos de cada aluno.
total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui

# %%
# 3) Seu código aqui
# Calcule o porcentual geral de cada aluno.
porcentual = round(total / 0.90, 2)

# %%
# 4) Seu código aqui
# Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?
aprovados = total[total['Qt_acertos'] > 45]
aprovados
aprovados['Qt_acertos'].count()
# Out:
# 31

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
result = pd.concat([df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui, total, porcentual], axis=1)
result.columns=['df_mat','df_por', 'df_geo', 'df_ing', 'df_his', 'df_fis', 'df_qui', 'total', 'porcentual']
result
# Out:
#     df_mat  df_por  df_geo  df_ing  df_his  df_fis  df_qui  total  porcentual
# 0        6       7       7       3       1       8       3     35       38.89
# 1       19      10       0       0       0      11       8     48       53.33
# 2       14      16       0       5       7       4       4     50       55.56
# 3       10       7       3       4       0       0       8     32       35.56
# 4        7       2       2       7       0       9       3     30       33.33
# ..     ...     ...     ...     ...     ...     ...     ...    ...         ...
# 95       6       4       7       1       4       9       3     34       37.78
# 96       8       1       4       6       1       4       3     27       30.00
# 97      23       5       0       2       4       1       5     40       44.44
# 98       0      10       3       1       5      10      11     40       44.44
# 99      11      15       0       1       6       7       2     42       46.67
#
# [100 rows x 9 columns]

# %%
#desqualificados por zerar em matemática, física ou química.
# result[result['df_mat'] != 0]

result_eliminados = result[
    (result['df_mat'] == 0) |  (result['df_fis'] == 0) |  (result['df_qui'] == 0)
]
result_eliminados
# Out:
#     df_mat  df_por  df_geo  df_ing  df_his  df_fis  df_qui  total  porcentual
# 3       10       7       3       4       0       0       8     32       35.56
# 6        6       0       7       7       5       0       4     29       32.22
# 10      10       8       3       2       1       7       0     31       34.44
# 12      20       8       3       7       1       0       3     42       46.67
# 14       7      11       1       7       1       4       0     31       34.44
# 20      23      11       6       5       6       2       0     53       58.89
# 25       0       4       7       4       0       4       8     27       30.00
# 26      11      14       6       2       7       0       0     40       44.44
# 27      21      13       1       5       7       3       0     50       55.56
# 33      14       8       0       5       6       6       0     39       43.33
# 35      11      14       6       3       3       0      11     48       53.33
# ...

# %%
# Quantos são esses alunos?

result_eliminados['total'].count()
# Out:
# 23

# %%
# Qual a média desses alunos em história e geografia?
# df_geo / 0.8
result_eliminados[{'df_geo', 'df_his'}] / 0.8
# Out:
# /tmp/ipykernel_30240/2088555884.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   result_eliminados[{'df_geo', 'df_his'}] / 0.8
#     df_geo  df_his
# 3     3.75    0.00
# 6     8.75    6.25
# 10    3.75    1.25
# 12    3.75    1.25
# 14    1.25    1.25
# 20    7.50    7.50
# 25    8.75    0.00
# 26    7.50    8.75
# 27    1.25    8.75
# 33    0.00    7.50
# 35    7.50    3.75
# 49    1.25    1.25
# 56    8.75    7.50
# 65    2.50    3.75
# 66    3.75    3.75
# 72    3.75    8.75
# 73    2.50    3.75
# 74    0.00    6.25
# 84    0.00    1.25
# 89    8.75    7.50
# 92    1.25    1.25
# 94    2.50    1.25
# 98    3.75    6.25

# %%
# Monte um DataFrame com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.
aprovados = result[
    (result['df_mat'] != 0) & (result['df_fis'] != 0) & (result['df_qui'] != 0)
]
aprovados
# Out:
#     df_mat  df_por  df_geo  df_ing  df_his  df_fis  df_qui  total  porcentual
# 0        6       7       7       3       1       8       3     35       38.89
# 1       19      10       0       0       0      11       8     48       53.33
# 2       14      16       0       5       7       4       4     50       55.56
# 4        7       2       2       7       0       9       3     30       33.33
# 5       20       2       5       3       2       9       9     50       55.56
# ..     ...     ...     ...     ...     ...     ...     ...    ...         ...
# 93      12      16       5       5       6       6       6     56       62.22
# 95       6       4       7       1       4       9       3     34       37.78
# 96       8       1       4       6       1       4       3     27       30.00
# 97      23       5       0       2       4       1       5     40       44.44
# 99      11      15       0       1       6       7       2     42       46.67
#
# [77 rows x 9 columns]

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-e45b1ab6-500c-4f78-a408-7e62ff651112.c000.csv'

# %%
df = pd.read_csv(arquivo, sep=';')
totalVacinados = df['document_id'].count()
totalVacinados
# Out:
# /tmp/ipykernel_30240/1623073395.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(arquivo, sep=';')
# 388617

# %%
df
# Out:
#                                       document_id  \
# 0       eedcf2ac-b593-4130-ab7a-2a42969cc93f-i0b0
# 1       d4cc82d9-eb49-46df-8718-9c6d3501c38d-i0b0
# 2       e1eda6bc-7d31-434e-aef7-cf5a4755d8cf-i0b0
# 3       d4ea5511-96fb-4f7e-b7b0-0435e7b83b5a-i0b0
# 4       d2e6775f-0969-45ed-98e6-46582569f879-i0b0
# ...                                           ...
# 388612  0620ad30-b67d-48f0-9ea8-ab5f3d60c300-i0b0
# 388613  063a0f51-f32d-46e4-bfa8-50ae018f9c5b-i0b0
# 388614  0662e53a-3e48-4fd7-a612-16e14f0082f4-i0b0
# 388615  068bdeee-f4b2-421e-acad-e2aff4688b2a-i0b0
# 388616  069750ec-b8c2-46fe-ad70-722a71a3bf7b-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       ab708de1dda42bf238b978943dfd3a8526e6583811224a...              10
# 1       84503404ddbbd400529058f34a22bd27fce11f1a52c492...              27
# 2       e1d98f2a4dd0464b1c8e2ae565bcd6a4497201d51f4c25...              33
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388617 entries, 0 to 388616
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               388617 non-null  object
#  1   paciente_id                               388617 non-null  object
#  2   paciente_idade                            388617 non-null  int64
#  3   paciente_dataNascimento                   388617 non-null  object
#  4   paciente_enumSexoBiologico                388617 non-null  object
#  5   paciente_racaCor_codigo                   388617 non-null  int64
#  6   paciente_racaCor_valor                    388617 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         386198 non-null  object
#  8   paciente_endereco_coPais                  386202 non-null  object
#  9   paciente_endereco_nmMunicipio             386201 non-null  object
# ...

# %%
# 1) Sua solução aqui
# Quantas vacinas estão registradas nessa base?
NumeroDeVacinas = df['vacina_nome'].nunique()
NumeroDeVacinas
# Out:
# 15

# %%
# 2)Quantos pacientes foram vacinados? (considere um paciente para cada valor único de paciente_id)
totalVacinados = df['document_id'].count()
totalVacinados
# Out:
# 388617

# %%
# 3)# Quantos pacientes únicos tomaram a primeira dose OBS: Há um caractere especial neste campo. Receba os valores do campo com o método .unique().
primeira_dose = df[df['vacina_descricao_dose'] == df['vacina_descricao_dose'].unique()[1]]
q_primeira_dose = primeira_dose['document_id'].count()
q_primeira_dose
# Out:
# 143811

# %%
# 3) solução alternativa

# %%
# 4)# Quantos pacientes com menos de 18 anos foram vacinados?
menor = df[df['paciente_idade' ] < 18]
menor['document_id'].count()
# Out:
# 78132

# %%
# 5)# Quantos estabelecimentos aplicaram vacina no Acre?
estabelecimentosAcre = df[df['estabelecimento_uf'] == 'AC']
estabelecimentosAcre['estabelecimento_razaoSocial'].nunique()
# Out:
# 63

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)crie uma cópia do DataFrame original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
menor
# Out:
#                                       document_id  \
# 0       eedcf2ac-b593-4130-ab7a-2a42969cc93f-i0b0
# 8       ded5786d-76fc-425a-9ee6-42db617d3b54-i0b0
# 12      ac44fdea-805e-499b-995d-187f04ef2c68-i0b0
# 16      b245c75e-b1f7-4975-b333-5dce0fc4aac9-i0b0
# 17      d5f3ffb8-cb57-4bfd-8ccc-4fb16a08a14a-i0b0
# ...                                           ...
# 388586  03741a3a-527f-4d99-820d-3b4d248ad0eb-i0b0
# 388588  038b482b-de5f-43a0-bd4d-5843edb415c7-i0b0
# 388601  04d47f9a-6700-4233-9b2f-b4357f1a4a66-i0b0
# 388608  0543cd1b-c0b8-4404-ba6c-94aabde14463-i0b0
# 388609  058fbde1-2073-405d-a212-9cd6d5585e39-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       ab708de1dda42bf238b978943dfd3a8526e6583811224a...              10
# 8       459451403a48ff803f4ab8f1090e406d6c7b8723c62cb9...              14
# 12      50dce1911981ce5321f32ace7797ad880d0502aa12211a...               5
# ...

# %%
# 2)crie uma lista das colunas desse DataFrame com o atributo de DataFrame .columns()
menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)Nesse DataFrame faça uma contagem do campo vacina_categoria_nome.
menor['vacina_categoria_nome'].count()
# Out:
# 57956

# %%
# 4)a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
lista_variaveis = ['estabelecimento_valor',
       'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']
menor_lista = menor[lista_variaveis]
menor_lista
# Out:
#         estabelecimento_valor             estabelecimento_razaoSocial  \
# 0                     5354072          PREFEITURA MUNICIPAL DE JORDAO
# 8                     6917291      PREFEITURA MUNICIPAL DE RIO BRANCO
# 12                    6917291      PREFEITURA MUNICIPAL DE RIO BRANCO
# 16                    3541592  PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 17                    6612385                   POLO BASE DE TARAUACA
# ...                       ...                                     ...
# 388586                2001039        PREFEITURA MUNICIPAL DE CAPIXABA
# 388588                6612385                   POLO BASE DE TARAUACA
# 388601                6917291      PREFEITURA MUNICIPAL DE RIO BRANCO
# 388608                2000504      PREFEITURA MUNICIPAL DE PORTO ACRE
# 388609                6917291      PREFEITURA MUNICIPAL DE RIO BRANCO
#
#                                  estalecimento_noFantasia  \
# 0       UNIDADE DE SAUDE DA FAMILIA ANTONIO RODRIGUES ...
# ...

# %%
# 5)usando o método .loc, selecione somente essas variáveis
menor_lista_loc = menor.loc[:,lista_variaveis]
menor_lista_loc
# Out:
#         estabelecimento_valor             estabelecimento_razaoSocial  \
# 0                     5354072          PREFEITURA MUNICIPAL DE JORDAO
# 8                     6917291      PREFEITURA MUNICIPAL DE RIO BRANCO
# 12                    6917291      PREFEITURA MUNICIPAL DE RIO BRANCO
# 16                    3541592  PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 17                    6612385                   POLO BASE DE TARAUACA
# ...                       ...                                     ...
# 388586                2001039        PREFEITURA MUNICIPAL DE CAPIXABA
# 388588                6612385                   POLO BASE DE TARAUACA
# 388601                6917291      PREFEITURA MUNICIPAL DE RIO BRANCO
# 388608                2000504      PREFEITURA MUNICIPAL DE PORTO ACRE
# 388609                6917291      PREFEITURA MUNICIPAL DE RIO BRANCO
#
#                                  estalecimento_noFantasia  \
# 0       UNIDADE DE SAUDE DA FAMILIA ANTONIO RODRIGUES ...
# ...

# %%
# 6) Aplique o método .drop_duplicates e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

df_menor_lista = menor_lista_loc.drop_duplicates()
df_menor_lista
# Out:
#         estabelecimento_valor                 estabelecimento_razaoSocial  \
# 0                     5354072              PREFEITURA MUNICIPAL DE JORDAO
# 8                     6917291          PREFEITURA MUNICIPAL DE RIO BRANCO
# 16                    3541592      PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 17                    6612385                       POLO BASE DE TARAUACA
# 19                    2002299     PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# ...                       ...                                         ...
# 205852                2001357  SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 310607                 755605                          USF BARRO VERMELHO
# 352783                2000814       SECRETARIA DE ESTADO DE SAUDE DO ACRE
# 365442                2832798      PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 388334                7565089          PREFEITURA MUNICIPAL DE RIO BRANCO
#
#                                  estalecimento_noFantasia  \
# ...
