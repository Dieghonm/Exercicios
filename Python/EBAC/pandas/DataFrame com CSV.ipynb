# %%
import pandas as pd
import numpy as np

# %%
vacAcre = pd.read_csv(
    'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-e45b1ab6-500c-4f78-a408-7e62ff651112.c000.csv',
    sep=';')
# Out:
# /tmp/ipykernel_23085/800046826.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   vacAcre = pd.read_csv(

# %%
vacAcre.head()
# Out:
#                                  document_id  \
# 0  eedcf2ac-b593-4130-ab7a-2a42969cc93f-i0b0
# 1  d4cc82d9-eb49-46df-8718-9c6d3501c38d-i0b0
# 2  e1eda6bc-7d31-434e-aef7-cf5a4755d8cf-i0b0
# 3  d4ea5511-96fb-4f7e-b7b0-0435e7b83b5a-i0b0
# 4  d2e6775f-0969-45ed-98e6-46582569f879-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  ab708de1dda42bf238b978943dfd3a8526e6583811224a...              10
# 1  84503404ddbbd400529058f34a22bd27fce11f1a52c492...              27
# 2  e1d98f2a4dd0464b1c8e2ae565bcd6a4497201d51f4c25...              33
# 3  33d18c6822aa11f1afd0dd50beae79dcc621c48e185612...              29
# 4  8a1d52c7b7d1c330b17c4e8d63003af54a9f620023451a...              23
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2012-03-04                          M                        3
# 1              1993-10-22                          F                       99
# ...

# %%
vacAcre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388617 entries, 0 to 388616
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               388617 non-null  object
#  1   paciente_id                               388617 non-null  object
#  2   paciente_idade                            388617 non-null  int64
#  3   paciente_dataNascimento                   388617 non-null  object
#  4   paciente_enumSexoBiologico                388617 non-null  object
#  5   paciente_racaCor_codigo                   388617 non-null  int64
#  6   paciente_racaCor_valor                    388617 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         386198 non-null  object
#  8   paciente_endereco_coPais                  386202 non-null  object
#  9   paciente_endereco_nmMunicipio             386201 non-null  object
# ...

# %%
vacAcreReduzido = vacAcre[:2000].copy()
vacAcreReduzido
# Out:
#                                     document_id  \
# 0     eedcf2ac-b593-4130-ab7a-2a42969cc93f-i0b0
# 1     d4cc82d9-eb49-46df-8718-9c6d3501c38d-i0b0
# 2     e1eda6bc-7d31-434e-aef7-cf5a4755d8cf-i0b0
# 3     d4ea5511-96fb-4f7e-b7b0-0435e7b83b5a-i0b0
# 4     d2e6775f-0969-45ed-98e6-46582569f879-i0b0
# ...                                         ...
# 1995  30b7bd26-e1de-4306-902c-105b6446324d-i0b0
# 1996  af93f476-191a-40f0-997b-f7ac568b63ce-i0b0
# 1997  2db2faed-c258-4d3f-ba70-7517bd4eab06-i0b0
# 1998  b17e1349-b493-46a8-834c-8dfa5928036f-i0b0
# 1999  4e15a576-7404-42fe-8bd2-724689b46584-i0b0
#
#                                             paciente_id  paciente_idade  \
# 0     ab708de1dda42bf238b978943dfd3a8526e6583811224a...              10
# 1     84503404ddbbd400529058f34a22bd27fce11f1a52c492...              27
# 2     e1d98f2a4dd0464b1c8e2ae565bcd6a4497201d51f4c25...              33
# 3     33d18c6822aa11f1afd0dd50beae79dcc621c48e185612...              29
# ...

# %%
vacAcreReduzido['f1_capital'] = 0

# %%
vacAcreReduzido['paciente_endereco_nmMunicipio'] == 'RIO BRANCO'
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1995     True
# 1996    False
# 1997     True
# 1998    False
# 1999     True
# Name: paciente_endereco_nmMunicipio, Length: 2000, dtype: bool

# %%
vacAcreReduzido.loc[vacAcreReduzido['paciente_endereco_nmMunicipio'] == 'RIO BRANCO', 'f1_capital'] = 1

# %%
vacAcreReduzido[['paciente_endereco_nmMunicipio','f1_capital']]
# Out:
#      paciente_endereco_nmMunicipio  f1_capital
# 0                           JORDAO           0
# 1                     ASSIS BRASIL           0
# 2                       ACRELANDIA           0
# 3                       RIO BRANCO           1
# 4                       RIO BRANCO           1
# ...                            ...         ...
# 1995                    RIO BRANCO           1
# 1996                EPITACIOLANDIA           0
# 1997                    RIO BRANCO           1
# 1998           SANTA ROSA DO PURUS           0
# 1999                    RIO BRANCO           1
#
# [2000 rows x 2 columns]

# %%
vacAcreReduzido['f1_capital'].sum()
# Out:
# 948

# %%
vacAcreReduzido['paciente_idade'].mean()
# Out:
# 34.623

# %%
#-----------------------------Outro csv-----------------------------

# %%
aprovacoes = pd.read_csv(
    'https://dadosabertos.bndes.gov.br/dataset/bce5a865-e766-4a7a-b537-9499c81275b6/resource/08f7a11c-48e0-4d3e-9a75-d95641657ebf/download/aprovacoes-por-uf-aprovacoes.csv',
    sep=';',
    decimal=','
)

# %%
aprovacoes.head(2)
# Out:
#     ano  mes      acre  amapa  amazonas       para  rondonia  roraima  \
# 0  1995    1  0.418697    0.0  2.234138   1.846492  1.044738      0.0
# 1  1995    2  0.045784    0.0  2.745178  42.480852  0.369604      0.0
#
#    tocantins   alagoas  ...  minas_gerais  rio_de_janeiro   sao_paulo  \
# 0   0.435302  3.903460  ...     24.211613      121.274922  160.955111
# 1   0.642143  2.293343  ...     26.779819       43.421296  150.042871
#
#       parana  rio_grande_do_sul  santa_catarina  distrito_federal     goias  \
# 0  44.503625          37.595270       35.303492          1.943748  8.347732
# 1  30.004889         127.624211       25.617710          6.737180  4.228323
#
#    mato_grosso  mato_grosso_do_sul
# 0    16.279153           10.268135
# 1    17.336139            2.984955
#
# [2 rows x 29 columns]

# %%
aprovacoes['ano'].unique()
# Out:
# array([1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024])

# %%
aprovacoes['ano'].nunique()
# Out:
# 30

# %%
aprovacoes['ano'].unique()
